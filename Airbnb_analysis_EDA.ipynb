# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilthenge/Airbnb_analysis/blob/main/Airbnb_analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Aspiration DS team
# ##### **Team Member 1 -** Chetan S Gode
# ##### **Team Member 2 -** Nikhil Thenge
# ##### **Team Member 3 -** Pawan Patel
# ##### **Team Member 4 -** Harsh Mehta
# ##### **Team Member 5 **** - ** Sanket Nibalkar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# #### Since 2008 Guest and Host used AirBnb to expand travelling possibility and present more unique and personalise way to experiencing the World.Today AirBnb become one of kind of service that is used and recognized by whole world.
#
# #### AirBnb is a plateform where people can rent their house to other people and earn money from people.AirBnb has provided different type of properites according to need of person to person.
#
# ####  In data set, there is available three different category of room ,with different location,area, rate of room,availability,hoster,service and other data available. So we have to find out best input from that data so it helps to expand AirBnb business and also provide good service to consumers.
# #### AirBnb nyc_2019 data set has approximate 49000 observation and 19 variable so we have to check all that data and give best output from that data.

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/nikhilthenge/Airbnb_analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
# #### We have to find out percentage of different types of room booking in whole business.
# #### We have to compare rate of different types of room with considering different variable like area,price,service,etc.
# #### We have to check people prefer to use service or not.
# ####Check future possibility.
# ####We will find the neighbor hood area which have least posting of properties and preferred area by customers so that it will help airbnb to make strategy to increase revenue from such areas also.
# #### Finding out avaibality and demand of properties in particular area throuhout the year.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ####Busineess Objective is simple to increase revenue using data wrangling techniques analyzing the data.Also to know what more features or services can be provided/improved based on number of reviews received from each area.Ultimately to make customer experience better.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
# %lsmagic
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset (pls provide file path of you directory )
file = '/content/drive/MyDrive/csv_files/Airbnb NYC 2019 (1).csv'

# %%
df = pd.read_csv(file)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
##to check size of rows

df.index
# Out:
# RangeIndex(start=0, stop=48895, step=1)

# %%
##to check no of column
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
##to check shape of data

df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
##check duplicate value in data
df.duplicated()
df.duplicated().value_counts()
###here is no duplicate values
# Out:
# False    48895
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# missing some name of property in data so replace it with name "missing name"
#Check list
df[df["name"].isna()]
#count the number 
df["name"].isna().sum()
# Out:
# 16

# %%
#replace that none missing name with "missing name"
df["name"].fillna("missing name",inplace=True)
df["name"]
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                          Cozy Entire Floor of Brownstone
# 4         Entire Apt: Spacious Studio/Loft by central park
#                                ...
# 48890      Charming one bedroom - newly renovated rowhouse
# 48891        Affordable room in Bushwick/East Williamsburg
# 48892              Sunny Studio at Historical Neighborhood
# 48893                 43rd St. Time Square-cozy single bed
# 48894    Trendy duplex in the very heart of Hell's Kitchen
# Name: name, Length: 48895, dtype: object

# %%
# missing some "host_name" of property in data so replace it with name "missing host_name"
#Check list
df[df["host_name"].isna()]
#count number
df["host_name"].isna().sum()
# Out:
# 21

# %%
# Replace that host_name (none) with "missing host_name"
df["host_name"].fillna("missing host_name",inplace = True)
df["host_name"]
# Out:
# 0                 John
# 1             Jennifer
# 2            Elisabeth
# 3          LisaRoxanne
# 4                Laura
#              ...
# 48890          Sabrina
# 48891          Marisol
# 48892    Ilgar & Aysel
# 48893              Taz
# 48894       Christophe
# Name: host_name, Length: 48895, dtype: object

# %%
# missing some 'last_review' date so we assume today date ie. "2023-03-05"
#Check list
df[df["last_review"].isna()]
#count number
df["last_review"].isna().sum()
# Out:
# 10052

# %%
# here is near almost 1\5th of last review data(Date) is missing but review is available in other column we cannot ignore it
#replace that last_review (none) with "2019-12-31"
df["last_review"].fillna("2019-12-31",inplace=True)
df["last_review"]
# Out:
# 0        2018-10-19
# 1        2019-05-21
# 2        2019-12-31
# 3        2019-07-05
# 4        2018-11-19
#             ...
# 48890    2019-12-31
# 48891    2019-12-31
# 48892    2019-12-31
# 48893    2019-12-31
# 48894    2019-12-31
# Name: last_review, Length: 48895, dtype: object

# %%
# check data types of review dates 
df['last_review'].dtype
# Out:
# dtype('O')

# %%
# convert date type (object) to datetime format

df['last_review']=df['last_review'].apply(lambda x : datetime.strptime(x,'%Y-%m-%d'))
df['last_review']
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2       2019-12-31
# 3       2019-07-05
# 4       2018-11-19
#            ...
# 48890   2019-12-31
# 48891   2019-12-31
# 48892   2019-12-31
# 48893   2019-12-31
# 48894   2019-12-31
# Name: last_review, Length: 48895, dtype: datetime64[ns]

# %%
# missing some "reviews_per_month" of property in data so replace it with name "0"
#check list
df[df["reviews_per_month"].isna()]
#count number
df["reviews_per_month"].isna().sum()
# Out:
# 10052

# %%
#replace that value
df["reviews_per_month"].fillna('0',inplace=True)
df["reviews_per_month"]
# Out:
# 0        0.21
# 1        0.38
# 2           0
# 3        4.64
# 4         0.1
#          ...
# 48890       0
# 48891       0
# 48892       0
# 48893       0
# 48894       0
# Name: reviews_per_month, Length: 48895, dtype: object

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
# There are total 16 variable and approximate 49k observation and no duplicate value inside it.
# here is 16 observation has missing name so we have given the name to that as "missing name".
# 21 host name has missed so gave name "missing host_name".
# Near about 10K review missing so replace it with 31-12-2019
# Near about 10K "reviews_per_month" missing so replaced by 0.
# In Data Set minimum price showing zero for 11 observation so it is negligible compare to total data so we are ignoring the same.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.888400e+04  4.888400e+04  48884.000000  48884.000000  48884.000000
# mean   1.901679e+07  6.762203e+07     40.728953    -73.952176    152.755053
# std    1.098432e+07  7.861666e+07      0.054532      0.046159    240.170260
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.470548e+06  7.817310e+06     40.690100    -73.983080     69.000000
# 50%    1.967574e+07  3.079257e+07     40.723080    -73.955685    106.000000
# 75%    2.915297e+07  1.074344e+08     40.763120    -73.936290    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# count    48884.000000       48884.000000                    48884.000000
# mean         7.029887          23.271991                        7.144628
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * id- showing unique ID of properties that register in AirBnb.
# * host_id - giveing unique id to host
# * host name - showing host name
# * neighbourhood_group- showing location
# * neighourhood -showing area
# * room_types - showing types of listing
# * price- showing rate
# * minimum_nights- minimum night to be paid for
# * number_of_reviews- showing review
# * last_review- showing content of last review
# * reviews_per_month- showing number of content per month
# * calculated_host_listings_count- total count show
# * availability_365 -showing available per year

# %%
# Dataset Columns

df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
#create function to calculate unique value and count 
def unique_val(aa):
  lis=aa.unique()
  num=aa.nunique()
  return lis,num

# %%
# Check Unique Values and no of unique value of  "id"
unique_val(df['id'])
# Out:
# (array([    2539,     2595,     3647, ..., 36485431, 36485609, 36487245]),
#  48884)

# %%
# Check Unique Values and no of unique value of  "name"
unique_val(df['name'])
# Out:
# (array(['Clean & quiet apt home by the park', 'Skylit Midtown Castle',
#         'THE VILLAGE OF HARLEM....NEW YORK !', ...,
#         'Sunny Studio at Historical Neighborhood',
#         '43rd St. Time Square-cozy single bed',
#         "Trendy duplex in the very heart of Hell's Kitchen"], dtype=object),
#  47895)

# %%
# Check Unique Values and no of unique value of  "host_id"
unique_val(df['host_id'])
# Out:
# (array([     2787,      2845,      4632, ..., 274321313,  23492952,
#          68119814]),
#  37455)

# %%
# Check Unique Values and no of unique value of  "host_name"
unique_val(df['host_name'])
# Out:
# (array(['John', 'Jennifer', 'Elisabeth', ..., 'Abayomi', 'Alberth',
#         'Ilgar & Aysel'], dtype=object),
#  11451)

# %%
# Check Unique Values and no of unique value of  "neighbourhood_group"
unique_val(df['neighbourhood_group'])
# Out:
# (array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#        dtype=object),
#  5)

# %%
# Check Unique Values and no of unique value of  "neighbourhood"
unique_val(df['neighbourhood'])
# Out:
# (array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#         'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#         'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#         'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#         'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#         'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#         'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#         'SoHo', 'Upper East Side', 'Prospect Heights',
#         'Washington Heights', 'Woodside', 'Brooklyn Heights',
#         'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#         'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#         'Highbridge', 'Financial District', 'Ridgewood',
#         'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#         'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
# Check Unique Values and no of unique value of  "room_type"
unique_val(df['room_type'])
# Out:
# (array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object), 3)

# %%
# Check Unique Values and no of unique value of  "price"
unique_val(df['price'])
# Out:
# (array([  149,   225,   150,    89,    80,   200,    60,    79,   135,
#            85,   120,   140,   215,    99,   190,   299,   130,   110,
#            44,   180,    50,    52,    55,    70,    35,    40,    68,
#           115,   151,   228,   144,    69,    49,   375,   250,   275,
#           230,    51,    65,   105,    95,   145,   285,    94,   800,
#           131,    98,   100,   125,   175,   500,   101,   220,    59,
#           350,   199,   325,   235,   170,   400,    75,    90,   185,
#            77,    76,   160,   195,   156,   219,   475,   165,   196,
#            83,   123,   265,   249,   121,    45,    71,    64,   159,
#           189,   239,   305,   155,    92,    36,    37,   205,    39,
#           390,   129,   212,   124,   122,   109,   575,   229,   169,
#           113,   179,   349,   139,   650,    67,   599,   211,   290,
#            87,   395,   260,    97,   132,   141,   495,   259,    96,
# ...

# %%
# Check Unique Values and no of unique value of  "minimum_nights"
unique_val(df['minimum_nights'])
# Out:
# (array([   1,    3,   10,   45,    2,    5,    4,   90,    7,   14,   60,
#           29,   30,  180,    9,   31,    6,   15,    8,   26,   28,  200,
#           50,   17,   21,   11,   25,   13,   35,   27,   18,   20,   40,
#           44,   65,   55,  120,  365,  122,   19,  240,   88,  115,  150,
#          370,   16,   80,  181,  265,  300,   59,  185,  360,   56,   12,
#           70,   39,   24,   32, 1000,  110,  270,   22,   75,  250,   62,
#           23, 1250,  364,   74,  198,  100,  500,   43,   91,  480,   53,
#           99,  160,   47,  999,  186,  366,   68,   93,   87,  183,  299,
#          175,   98,  133,  354,   42,   33,   37,  225,  400,  105,  184,
#          153,  134,  222,   58,  210,  275,  182,  114,   85,   36]),
#  109)

# %%
# Check Unique Values and no of unique value of  "number_of_reviews"
unique_val(df['number_of_reviews'])
# Out:
# (array([  9,  45,   0, 270,  74,  49, 430, 118, 160,  53, 188, 167, 113,
#          27, 148, 198, 260, 130,  39,  71,  88,  19,  58, 108,  29, 242,
#         197, 273, 168, 231, 214, 245,  15,  25,  81,  97,  11, 248,  61,
#         135, 112,  73,  82, 328, 105, 289, 138,  21,  42,   5,  66, 143,
#         191,   4, 338, 106, 190,  23, 142,  54,  70,  16,  94, 194,   2,
#         174,  24, 166,   1,  30, 139, 233,  68,  46, 335, 162, 170, 334,
#          12, 467,   7,  38, 324, 115, 354, 195,  13,  36,  63, 155, 193,
#          32,  50,  26, 426, 227,  84,   3,  10, 124, 240, 200,  79,  34,
#         134, 126, 234, 202,  28, 309,  14,  80, 294, 150,  47, 219, 114,
#         213,  86,  18, 206, 122,  33,  52,  51, 199,  41, 109, 151, 285,
#         375,   6, 358, 226, 104, 204, 253, 129,  37,  69, 192,  17, 222,
#         205, 458, 183, 189, 127,  35, 171,  92, 238,  56, 111, 147, 177,
#         185,  62, 181, 333, 441, 279, 203, 210,  64, 132,  20,  67, 187,
# ...

# %%
# Check Unique Values and no of unique value of  "last_review"
unique_val(df['last_review'])
# Out:
# (array(['2018-10-19T00:00:00.000000000', '2019-05-21T00:00:00.000000000',
#         '2019-12-31T00:00:00.000000000', ...,
#         '2017-12-23T00:00:00.000000000', '2018-01-29T00:00:00.000000000',
#         '2018-03-29T00:00:00.000000000'], dtype='datetime64[ns]'),
#  1765)

# %%
# Check Unique Values and no of unique value of  "calculated_host_listings_count"
unique_val(df['calculated_host_listings_count'])
# Out:
# (array([  6,   2,   1,   4,   3,   5,   7,  13,  28,  11,   8,   9,  52,
#          18,  15,  19,  10,  39,  26,  29,  12,  21,  96,  14,  34,  43,
#         121,  37,  49,  31,  91,  16,  87,  33,  23,  50,  20,  25, 232,
#          17,  47, 103,  65,  30,  27, 327,  32]),
#  47)

# %%
# Check Unique Values and no of unique value of  "availability_365"
unique_val(df['availability_365'])
# Out:
# (array([365, 355, 194,   0, 129, 220, 188,   6,  39, 314, 333,  46, 321,
#          12,  21, 249, 347, 364, 304, 233,  85,  75, 311,  67, 255, 284,
#         359, 269, 340,  22,  96, 345, 273, 309,  95, 215, 265, 192, 251,
#         302, 140, 234, 257,  30, 301, 294, 320, 154, 263, 180, 231, 297,
#         292, 191,  72, 362, 336, 116,  88, 224, 322, 324, 132, 295, 238,
#         209, 328,  38,   7, 272,  26, 288, 317, 207, 185, 158,   9, 198,
#         219, 342, 312, 243, 152, 137, 222, 346, 208, 279, 250, 164, 298,
#         260, 107, 199, 299,  20, 318, 216, 245, 189, 307, 310, 213, 278,
#          16, 178, 275, 163,  34, 280,   1, 170, 214, 248, 262, 339,  10,
#         290, 230,  53, 126,   3,  37, 353, 177, 246, 225,  18, 343, 326,
#         162, 240, 363, 247, 323, 125,  91, 286,  60,  58, 351, 201, 232,
#         258, 341, 244, 329, 253, 348,   2,  56,  68, 360,  76,  15, 226,
#         349,  11, 316, 281, 287,  14,  86, 261, 331,  51, 254, 103,  42,
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48884 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48884 non-null  int64
#  1   name                            48884 non-null  object
#  2   host_id                         48884 non-null  int64
#  3   host_name                       48884 non-null  object
#  4   neighbourhood_group             48884 non-null  object
#  5   neighbourhood                   48884 non-null  object
#  6   latitude                        48884 non-null  float64
#  7   longitude                       48884 non-null  float64
#  8   room_type                       48884 non-null  object
#  9   price                           48884 non-null  int64
#  10  minimum_nights                  48884 non-null  int64
#  11  number_of_reviews               48884 non-null  int64
# ...

# %%
# (2) getting numerical value description
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.888400e+04  4.888400e+04  48884.000000  48884.000000  48884.000000
# mean   1.901679e+07  6.762203e+07     40.728953    -73.952176    152.755053
# std    1.098432e+07  7.861666e+07      0.054532      0.046159    240.170260
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.470548e+06  7.817310e+06     40.690100    -73.983080     69.000000
# 50%    1.967574e+07  3.079257e+07     40.723080    -73.955685    106.000000
# 75%    2.915297e+07  1.074344e+08     40.763120    -73.936290    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# count    48884.000000       48884.000000                    48884.000000
# mean         7.029887          23.271991                        7.144628
# ...

# %%
#(3) check types of "room_type" in total business
types_of_room_type=df['room_type'].value_counts().reset_index().rename(columns={"index":"room types","room_type":"total"})
types_of_room_type
# Out:
#         room types  total
# 0  Entire home/apt  25407
# 1     Private room  22319
# 2      Shared room   1158

# %%
#(4) Check no of neighbourhood_group in data (it is showing no room in specific location)

neighbourhood_group = df.groupby('neighbourhood_group')['id'].count().reset_index().rename(columns ={'id':'number of apartment'})
neighbourhood_group
# Out:
#   neighbourhood_group  number of apartment
# 0               Bronx                 1090
# 1            Brooklyn                20095
# 2           Manhattan                21660
# 3              Queens                 5666
# 4       Staten Island                  373

# %%
#(5) here this is showing top 10 neighbourhood (ie. Area wise) room register in AirBnb
neighbourhood_count= df.groupby('neighbourhood')['id'].count().reset_index().sort_values(by='id', ascending= False).rename(columns={'id':'Apartment'}).head(10)
neighbourhood_count
# Out:
#           neighbourhood  Apartment
# 214        Williamsburg       3919
# 13   Bedford-Stuyvesant       3710
# 94               Harlem       2658
# 28             Bushwick       2462
# 202     Upper West Side       1971
# 95       Hell's Kitchen       1958
# 64         East Village       1853
# 201     Upper East Side       1798
# 51        Crown Heights       1564
# 127             Midtown       1545

# %%
#(6) room_with_respect_to_neighbourhood check here
room_with_respect_to_neighbourhood =df.groupby(['neighbourhood_group','room_type'])['id'].count().reset_index().rename(columns={'id':'Total'})
room_with_respect_to_neighbourhood
# Out:
#    neighbourhood_group        room_type  Total
# 0                Bronx  Entire home/apt    379
# 1                Bronx     Private room    651
# 2                Bronx      Shared room     60
# 3             Brooklyn  Entire home/apt   9558
# 4             Brooklyn     Private room  10126
# 5             Brooklyn      Shared room    411
# 6            Manhattan  Entire home/apt  13198
# 7            Manhattan     Private room   7982
# 8            Manhattan      Shared room    480
# 9               Queens  Entire home/apt   2096
# 10              Queens     Private room   3372
# 11              Queens      Shared room    198
# 12       Staten Island  Entire home/apt    176
# 13       Staten Island     Private room    188
# 14       Staten Island      Shared room      9

# %%
#(7) room_with_respect_to_neighbourhood check here in form of pivot table
room_with_respect_to_neighbourhood.pivot(index='neighbourhood_group', columns='room_type', values='Total' )
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           651           60
# Brooklyn                        9558         10126          411
# Manhattan                      13198          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
#(8) checking 'room_types' of average price
room_type_price= df.groupby(['room_type'])['price'].mean().reset_index()
room_type_price
# Out:
#          room_type       price
# 0  Entire home/apt  211.810918
# 1     Private room   89.809131
# 2      Shared room   70.248705

# %%
#(9)location_wise_average_price distribution show in below coding

location_wise_average_price = df.groupby([ 'neighbourhood_group'])['price'].mean().reset_index().sort_values('price' ,ascending=False)
location_wise_average_price
# Out:
#   neighbourhood_group       price
# 2           Manhattan  196.884903
# 1            Brooklyn  124.438915
# 4       Staten Island  114.812332
# 3              Queens   99.517649
# 0               Bronx   87.577064

# %%
# (10) average room_price_distribution in area with different room_types
room_price_distribution =df.groupby(['neighbourhood_group','room_type'])['price'].mean().reset_index().sort_values('price' ,ascending=False)
room_price_distribution
# Out:
#    neighbourhood_group        room_type       price
# 6            Manhattan  Entire home/apt  249.257994
# 3             Brooklyn  Entire home/apt  178.346202
# 12       Staten Island  Entire home/apt  173.846591
# 9               Queens  Entire home/apt  147.050573
# 0                Bronx  Entire home/apt  127.506596
# 7            Manhattan     Private room  116.776622
# 8            Manhattan      Shared room   88.977083
# 4             Brooklyn     Private room   76.545428
# 10              Queens     Private room   71.762456
# 11              Queens      Shared room   69.020202
# 1                Bronx     Private room   66.890937
# 13       Staten Island     Private room   62.292553
# 2                Bronx      Shared room   59.800000
# 14       Staten Island      Shared room   57.444444
# 5             Brooklyn      Shared room   50.773723

# %%
#(11) showing high rate of room_type area wise
expensive_locality =df.groupby(['neighbourhood'])['price'].mean().sort_values( ascending=False).head(10).reset_index()
# expensive_locality= expensive_locality.sort_values(by= 'price', ascending= True)
expensive_locality
# Out:
#        neighbourhood       price
# 0     Fort Wadsworth  800.000000
# 1            Woodrow  700.000000
# 2            Tribeca  490.638418
# 3           Sea Gate  487.857143
# 4          Riverdale  442.090909
# 5       Prince's Bay  409.500000
# 6  Battery Park City  367.557143
# 7  Flatiron District  341.925000
# 8      Randall Manor  336.000000
# 9               NoHo  295.717949

# %%
#(12) Showing  location wise minimum average rate of room 
affordable_locality= df.groupby('neighbourhood')['price'].mean().sort_values( ascending=True).head(10).reset_index()
affordable_locality
# Out:
#     neighbourhood      price
# 0     Bull's Head  47.333333
# 1     Hunts Point  50.500000
# 2         Tremont  51.545455
# 3       Soundview  53.466667
# 4        New Dorp  57.000000
# 5       Bronxdale  57.105263
# 6  New Dorp Beach  57.400000
# 7      Grant City  57.666667
# 8         Concord  58.192308
# 9      Mount Eden  58.500000

# %%
#(13)most_reviewed_host showing

## first change 'reviews_per_month' from object to float form
df['reviews_per_month']=df['reviews_per_month'].apply(lambda x : float(x))
most_reviewed_host =df.groupby(['name','host_name'])['reviews_per_month'].max().reset_index().sort_values(by='reviews_per_month',ascending=False).head(10)
most_reviewed_host
# Out:
#                                                     name host_name  \
# 18823  Enjoy great views of the City in our Deluxe Room!   Row NYC
# 21296           Great Room in the heart of Times Square!   Row NYC
# 26281                 Lou's Palace-So much for so little    Louann
# 23827  JFK Comfort.5 Mins from JFK Private Bedroom & ...   Nalicia
# 23819      JFK 2 Comfort 5 Mins from JFK Private Bedroom   Nalicia
# 23821      JFK 3 Comfort 5 Mins from JFK Private Bedroom   Nalicia
# 15437  Cozy Room Family Home LGA Airport NO CLEANING FEE  Danielle
# 17464  Cute Tiny Room Family Home by LGA NO CLEANING FEE  Danielle
# 48193                                 “For Heaven Cakes”     Brent
# 41226        Studio Apartment 6 minutes from JFK Airport  Lakshmee
#
#        reviews_per_month
# 18823              58.50
# 21296              27.95
# 26281              20.94
# 23827              19.75
# 23819              17.82
# 23821              16.81
# 15437              16.22
# ...

# %%
#(14)showing minimum stays with different room types
minimum_stays =df.groupby('room_type')['minimum_nights'].mean()
minimum_stays
# Out:
# room_type
# Entire home/apt    8.507262
# Private room       5.379004
# Shared room        6.434370
# Name: minimum_nights, dtype: float64

# %%
# (15) showing location area wise availability_room
availability_room =df.groupby(['neighbourhood_group'])['availability_365'].mean().reset_index().sort_values(by='availability_365', ascending=False).rename(columns={'availability_365':'Available per year'})
availability_room
# Out:
#   neighbourhood_group  Available per year
# 4       Staten Island          199.678284
# 0               Bronx          165.794495
# 3              Queens          144.451818
# 2           Manhattan          111.984580
# 1            Brooklyn          100.217318

# %%
#(16) showing expensive_host
expensive_host = df.groupby(['name','neighbourhood_group','neighbourhood'])['price'].max().reset_index().sort_values(by='price', ascending=False).head(10)
expensive_host
# Out:
#                                                     name neighbourhood_group  \
# 20018                Furnished room in Astoria apartment              Queens
# 1109                                 1-BR Lincoln Center           Manhattan
# 26965    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 40650                                 Spanish Harlem Apt           Manhattan
# 35804                Quiet, Clean, Lit @ LES & Chinatown           Manhattan
# 2217   2br - The Heart of NYC: Manhattans Lower East ...           Manhattan
# 7049   Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho           Manhattan
# 19532                                      Film Location            Brooklyn
# 18188          East 72nd Townhouse by (Hidden by Airbnb)           Manhattan
# 20260                               Gem of east Flatbush            Brooklyn
#
#          neighbourhood  price
# 20018          Astoria  10000
# 1109   Upper West Side  10000
# ...

# %%
#(17)showing most affordable host
most_affordable_host = df.groupby(['name','neighbourhood_group','neighbourhood'])['price'].min().reset_index().sort_values(by='price', ascending=True).head(10)
most_affordable_host
# Out:
#                                                     name neighbourhood_group  \
# 45793    Very Spacious bedroom, steps from CENTRAL PARK.           Manhattan
# 35812             Quiet, Cozy UES Studio Near the Subway           Manhattan
# 14006               Couch in Harlem Harvey Refugees only           Manhattan
# 23706                                            Jen Apt           Manhattan
# 16173                           Cozy feel at home studio           Manhattan
# 16592                 Cozy room in a three-bedroom House              Queens
# 23344                            IT'S SIMPLY CONVENIENT!              Queens
# 38902      Spacious 2-bedroom Apt in Heart of Greenpoint            Brooklyn
# 30662  Newly renovated, fully furnished room in Brooklyn            Brooklyn
# 6797                          Beautiful room in Bushwick            Brooklyn
#
#          neighbourhood  price
# 45793  Upper West Side     10
# 35812  Upper East Side     10
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# What actually we got from above data wrangling step by step explained as below:
# * 1) Got basic information about data.
#
# * 2)Got basic information about numeric value.
#
# * 3) We found that entire home/Apt has max registeration and shared room has minimum registration in business.
#
# * 4)There are total five locations where all the rooms register,max room register in Manhattan and min at staten Island.
#
# * 5)Here it is showing top ten room registration area wise Williamsburg has highest room registration
#
# * 6)Location wise different types of room registration showing in it.
#
# * 7)Showing average rate of room_types ,highest rate for Entire home/apt and lowest rate is for share room.
#
# * 8)Showing location wise average rate of room bronx has lowest rate whereas Manhattan has highest rate.
#
# * 9) Showing that location wise different types of room rate
# Entire house/apt has lowest price "Bronx" and highest price is here "Manhattan "
# share room has lowest price "Brooklyn " and highest price is here "Manhattan "
# private room has lowest price "Staten Island " and highest price is here "Manhattan ".
#
# * 10) Showing that top ten highest rate room in specific area,first number is coming "Fort Wadsworth".
#
# * 11)Showing that top ten lowest rate room in specific area,first number is coming "Bull's Head".
#
# * 12)Top ten rewies host name is showing.
#
# * 13)Showing minimum stay in specific room types.
#
# * 14)Showing that most available of room in location here "Staten Island" has highest available room every year and lowest available here "Brooklyn ".
#
# * 15)Showing that top 10 expensive host,first number came "Furnished room in Astoria apartment".
#
# * 16)Showing that top 10 affordable host,first number came "Very Spacious bedroom, steps from CENTRAL PARK."

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# First showing no. of room registered with airbnb in different categories.

#check unique value
df['room_type'].unique()
#check no of unique value
df['room_type'].nunique()
#count no of booking rrom types
df['room_type'].value_counts()
percentage_of_type_room=df['room_type'].value_counts()
print(percentage_of_type_room)
# Out:
# Entire home/apt    25407
# Private room       22319
# Shared room         1158
# Name: room_type, dtype: int64

# %%
# The visualisation of above data

plt.rcParams['figure.figsize']=(5,5)
percentage_of_type_room.plot(kind='pie',autopct='%.1f%%')
plt.title("Total Booking of different types of rooms")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# From the above pie chart we get the idea about the distribution percentage of room type preferred by customers listed in airbnb website.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart we can conclude that Entire home/Apt type room and private room has major share in AirBnb bussiness,only 7% difference while shared room are not preferred much by customers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Evaluating the insights,the most revenue comes from private room and entire home/Apt only as they are expensive too. Considering the increasing inflation and recession customers may not prefer expensive private room/Entire home in near future.So airbnb also needs to increase features and services for shared room also.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#(4) Check no of neighbourhood_group in data (it is showing no room in specific location)
neighbourhood_group = df.groupby('neighbourhood_group')['id'].count().reset_index().rename(columns ={'id':'number of apartment'})
neighbourhood_group
# Out:
#   neighbourhood_group  number of apartment
# 0               Bronx                 1090
# 1            Brooklyn                20095
# 2           Manhattan                21660
# 3              Queens                 5666
# 4       Staten Island                  373

# %%
sns.barplot(x='neighbourhood_group',y='number of apartment',data=neighbourhood_group)
plt.title("showing no room in specific location(neighbourhood group)")
plt.xlabel('neighbourhood_group')
plt.ylabel('no of roomtypes available')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart easily shows the number of rooms available in each neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar plot we can conclude that most room types availale in Manhattan and Brooklyn while Bronx and staten Island very few room type compare to other two.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As per the insights it will help airbnb to focus more on less available roomtype so that customers are not out of options. It brings negative customer experience when customer do not find rooms as per their preferrence for particular neighborhood group and they then choose other online platforms.
# This insight will help in customer retention.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
room_with_respect_to_neighbourhood =df.groupby(['neighbourhood_group','room_type'])['id'].count().reset_index().rename(columns={'id':'Total'})
#(7) room_with_respect_to_neighbourhood check here in form of pivot table
pivot=room_with_respect_to_neighbourhood.pivot(index='neighbourhood_group', columns='room_type', values='Total' )
pivot
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           651           60
# Brooklyn                        9558         10126          411
# Manhattan                      13198          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
#(7) different types of room_available_with_respect_to_neighbourhood (location) check here in form of pivot table

pivot.plot(kind='bar')
plt.title('different types of room_available_with_respect_to_neighbourhood (location)')
plt.xlabel('neighbourhood_group')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Directly specifies the difference between highest and lowest room service in specific location.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * With respect to neighbourhood group
#
# * Highest private_room at-Brooklyn and lowest private rooms at-Staten Island.
#
# * Highest Entire home/apt at-Manhattan and lowest Entire home/apt at-Staten Island.
#
# * Highest share_room at-Manhattan and lowest share_room at-Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here we have seen that min and max price has more difference.
# So we have checked price compability.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#(5) here is showing top 10 neighbourhood (ie. Area wise) room register in AirBnb
neighbourhood_count= df.groupby('neighbourhood')['id'].count().reset_index().sort_values(by='id', ascending= False).rename(columns={'id':'Apartment'}).head(10)
neighbourhood_count
# Out:
#           neighbourhood  Apartment
# 214        Williamsburg       3919
# 13   Bedford-Stuyvesant       3710
# 94               Harlem       2658
# 28             Bushwick       2462
# 202     Upper West Side       1971
# 95       Hell's Kitchen       1958
# 64         East Village       1853
# 201     Upper East Side       1798
# 51        Crown Heights       1564
# 127             Midtown       1545

# %%
neighbourhood_count.plot(kind='bar',x='neighbourhood',y='Apartment' )
plt.title('showing top 10 neighbourhood (ie. Area wise) room register in AirBnb')
plt.xlabel('neighbourhood (ie. Area wise)')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The above chart showing top 10 room booking area wise

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The highest number of room_booking is in a area "Williamsburg"

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * After analyzing the reviews from each top 10 neighborhood, airbnb will prioritize these area for more services. If demands are high in such areas then prices/commision can be increased.
#
# * From the chart if airbnb does not increases revenue or focus on areas where least booked room then it will have negative impact as airbnb has to take care of every type of customers from each area even if comissions are very less.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#(5) here is showing top 20 neighbourhood wise (ie. Area wise) different types of room register in AirBnb
neighbourhood_count= df.groupby(['neighbourhood','room_type'])['id'].count().reset_index().sort_values(by='id', ascending= False).rename(columns={'id':'Apartment'}).head(20)
pivot_table_diff_room_with_diff_neighbourhood=neighbourhood_count.pivot(index='neighbourhood', columns='room_type', values='Apartment' )
pivot_table_diff_room_with_diff_neighbourhood
# Out:
# room_type           Entire home/apt  Private room
# neighbourhood
# Bedford-Stuyvesant           1591.0        2034.0
# Bushwick                      678.0        1718.0
# Chelsea                       820.0           NaN
# Crown Heights                 759.0         780.0
# East Village                 1170.0         660.0
# Harlem                       1036.0        1573.0
# Hell's Kitchen               1187.0         672.0
# Midtown                      1100.0           NaN
# Upper East Side              1310.0           NaN
# Upper West Side              1256.0         675.0
# West Village                  653.0           NaN
# Williamsburg                 1890.0        1997.0

# %%
plt.rcParams['figure.figsize']=(7,7)
pivot_table_diff_room_with_diff_neighbourhood.plot(kind='bar')
plt.title('showing top 10 neighbourhood wise (ie. Area wise) different types of room register')
plt.xlabel('room types')
plt.ylabel("total")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Easy to compare different types of room in different areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here is difficult to say what is found inside from data so that we splite above data with respect to room type and give the output

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Top 20 room booking area wise doesnt have any share room.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Now we find average rate of different types of rooms

average_rate=df.groupby('room_type').agg({"price":["mean"]})
average_rate
# Out:
#                       price
#                        mean
# room_type
# Entire home/apt  211.810918
# Private room      89.809131
# Shared room       70.248705

# %%
from matplotlib import figure
average_rate.plot(kind='bar')
plt.rcParams['figure.figsize']=(5,4)
plt.title("average rate of different types of room")
plt.ylabel("differnt type of rooms rate (average)")
plt.xlabel("different types of room")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart is easy to understand the average price of room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# share_room has lowest fare as compare to other
#
# Entire home/apt has highest fare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Highest rate of private room has appr. double of its median

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# now we will check the mean,median,max and min price of room according to room types

agg_rate=df.groupby('room_type').agg({"price":["mean","median","max","min"]})
agg_rate
# Out:
#                       price
#                        mean median    max min
# room_type
# Entire home/apt  211.810918  160.0  10000  10
# Private room      89.809131   70.0  10000  10
# Shared room       70.248705   45.0   1800  10

# %%
agg_rate.plot(kind='bar', stacked = False)
plt.rcParams['figure.figsize']=(5,10)
plt.title("rate of different types of room")
plt.ylabel("differnt type of rooms rate ")
plt.xlabel("different types of room")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The above graph easity shows that min and max rate of room in specific types of room.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The difference between min & max and mean & max is very huge which shows that very few high price of all room types available.
# Most room types available under 2000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Most customers prefer good stay at affordable rates. This insight will help to continue to focus to retain the same prices.
#
# * Since there are very few high price stay available, elite rich customers might look for other platforms.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
